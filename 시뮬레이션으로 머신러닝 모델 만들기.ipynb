# %%
from sklearn.datasets import load_wine
import pandas as pd

wine=load_wine()


df=pd.DataFrame(wine['data'], columns=wine['feature_names'])
df['target']=wine['target']
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline  target
# 0                            3.92   1065.0       0
# 1                            3.40   1050.0       0
# 2                            3.17   1185.0       0
# 3                            3.45   1480.0       0
# 4                            2.93    735.0       0
# ..                            ...      ...     ...
# 173                          1.74    740.0       2
# 174                          1.56    750.0       2
# 175                          1.56    835.0       2
# 176                          1.62    840.0       2
# 177                          1.60    560.0       2
#
# [178 rows x 14 columns]

# %%
wine['target_names']
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

data, target=wine['data'], wine['target']

# %%
# rf=RandomForestClassifier(n_estimators=디폴트10, max_depth=디폴트none)

# %%
rf=RandomForestClassifier()

dic={'n_estimators': range(100,201,10),'max_depth': range(1,11)}

gs=GridSearchCV(estimator=rf, param_grid=dic, cv=3)
gs.fit(data,target)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': range(1, 11),
#                          'n_estimators': range(100, 201, 10)})

# %%
gs.best_params_
# Out:
# {'max_depth': 6, 'n_estimators': 130}

# %%
result=gs.cv_results_
df=pd.DataFrame(result)
df.to_excel('result.xlsx')

# %%
df
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.133648      0.002952         0.012845        0.003012
# 1         0.139528      0.001472         0.013214        0.002177
# 2         0.152789      0.003556         0.012627        0.000309
# 3         0.166640      0.007916         0.016346        0.002283
# 4         0.180167      0.002668         0.014949        0.000966
# ..             ...           ...              ...             ...
# 105       0.215758      0.004545         0.018850        0.002978
# 106       0.222426      0.006504         0.017492        0.000353
# 107       0.236185      0.005824         0.018920        0.000815
# 108       0.252193      0.004249         0.021801        0.001511
# 109       0.265311      0.001482         0.020408        0.000214
#
#     param_max_depth param_n_estimators  \
# 0                 1                100
# 1                 1                110
# 2                 1                120
# 3                 1                130
# 4                 1                140
# ..              ...                ...
# 105              10                160
# 106              10                170
# 107              10                180
# 108              10                190
# 109              10                200
#
#                                      params  split0_test_score  \
# 0     {'max_depth': 1, 'n_estimators': 100}           0.883333
# 1     {'max_depth': 1, 'n_estimators': 110}           0.883333
# 2     {'max_depth': 1, 'n_estimators': 120}           0.883333
# 3     {'max_depth': 1, 'n_estimators': 130}           0.900000
# 4     {'max_depth': 1, 'n_estimators': 140}           0.883333
# ..                                      ...                ...
# 105  {'max_depth': 10, 'n_estimators': 160}           0.950000
# 106  {'max_depth': 10, 'n_estimators': 170}           0.900000
# 107  {'max_depth': 10, 'n_estimators': 180}           0.950000
# 108  {'max_depth': 10, 'n_estimators': 190}           0.950000
# 109  {'max_depth': 10, 'n_estimators': 200}           0.950000
#
#      split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0             0.932203           1.000000         0.938512        0.047837
# 1             0.932203           1.000000         0.938512        0.047837
# 2             0.915254           0.983051         0.927213        0.041578
# 3             0.949153           1.000000         0.949718        0.040827
# 4             0.881356           0.983051         0.915913        0.047480
# ..                 ...                ...              ...             ...
# 105           0.915254           0.966102         0.943785        0.021218
# 106           0.915254           1.000000         0.938418        0.043988
# 107           0.932203           0.966102         0.949435        0.013845
# 108           0.898305           1.000000         0.949435        0.041519
# 109           0.915254           0.983051         0.949435        0.027681
#
#      rank_test_score
# 0                 78
# 1                 78
# 2                103
# 3                 24
# 4                109
# ..               ...
# 105               63
# 106               81
# 107               33
# 108               33
# 109               33
#
# [110 rows x 13 columns]

# %%
best=gs.best_estimator_

# %%
best.score(data,target)
# Out:
# 1.0
