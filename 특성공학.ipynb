# %%
import pandas as pd

perch=pd.read_csv('perch.csv')
target=perch['weight'].to_numpy()

# %%
perch2=pd.read_csv('perch2.csv').to_numpy()
# perch2 는 length, height, width 3개의 데이터
perch2.shape
# 56개의 데이터 3개의 특성
# Out:
# (56, 3)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(include_bias=False,degree=2)
perch_poly=poly.fit_transform(perch2)
perch_poly.shape
# 56개의 데이터가 있고 10개의 특성이 나옴
# Out:
# (56, 9)

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target=train_test_split(perch_poly,target)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
train_scaled=ss.fit_transform(train_input)
test_scaled=ss.transform(test_input)

# %%
import numpy as np

# %%
np.mean(train_scaled,axis=0)
# 0과 매우 가까운 값, 사실상 0이라고 봐야함
# Out:
# array([ 1.48029737e-16,  1.90323947e-16,  3.62144177e-16, -3.17206578e-17,
#         3.17206578e-17, -2.14114440e-16, -1.85037171e-17,  3.14563190e-16,
#        -3.70074342e-17])

# %%
np.std(train_scaled,axis=0)
# 스케일링된 데이터의 표준편차는 0
# Out:
# array([1., 1., 1., 1., 1., 1., 1., 1., 1.])

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(train_scaled,train_target)
# Out:
# LinearRegression()

# %%
lr.score(test_scaled,test_target)
# Out:
# 0.9897334841534922
